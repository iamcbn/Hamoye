# %% [markdown]
# <a href="https://colab.research.google.com/github/iamcbn/Hamoye/blob/Stage-A/Bruno_Stage_A_Hamoye.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing modules and loading the file

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'

df = pd.read_csv(url, encoding = 'latin1')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %% [markdown]
# # Question 1:
# What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

# %%
round(df.Y2017.describe(), 2)
# Out:
# count     59437.00
# mean        140.92
# std        1671.86
# min       -1582.00
# 25%           0.00
# 50%           0.10
# 75%           9.00
# max      190873.00
# Name: Y2017, dtype: float64

# %% [markdown]
# # Question 2
# Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
df.Element.unique()
# Out:
# array(['Total Population - Both sexes', 'Domestic supply quantity',
#        'Food supply (kcal/capita/day)',
#        'Protein supply quantity (g/capita/day)',
#        'Fat supply quantity (g/capita/day)', 'Production',
#        'Import Quantity', 'Stock Variation', 'Export Quantity', 'Feed',
#        'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
#        'Residuals', 'Food', 'Food supply quantity (kg/capita/yr)',
#        'Tourist consumption'], dtype=object)

# %%
df.groupby('Element').get_group('Stock Variation')[['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']].sum()
# Out:
# Y2014    58749.83
# Y2015    34910.99
# Y2016    33140.12
# Y2017    54316.91
# Y2018    20577.91
# dtype: float64

# %%
df[df.Element == 'Stock Variation'].sum()
# Out:
# Area Code                                                  571566
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                11329527
# Item            Cereals - Excluding BeerWheat and productsRice...
# Element Code                                             21464704
# Element         Stock VariationStock VariationStock VariationS...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                    58749.83
# Y2015                                                    34910.99
# Y2016                                                    33140.12
# Y2017                                                    54316.91
# Y2018                                                    20577.91
# dtype: object

# %% [markdown]
# # Question 3
# Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?

# %%
area_y2017 = df.groupby('Area')['Y2017'].sum().sort_values(ascending= True).reset_index()

area_y2017.iloc[6]
# Out:
# Area     Guinea-Bissau
# Y2017         19102.77
# Name: 6, dtype: object

# %% [markdown]
# # Question 6
# What is the total number of unique countries in the dataset?

# %%
df.Area.nunique()
# Out:
# 49

# %% [markdown]
# # Question 7
# What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
df.Y2017.isna().sum()
# Out:
# 1506

# %% [markdown]
# # Question 8
# If you have the following list
#
# lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
#
# col = [‘Age’,’Nationality’,’Overall’]
#
# How do you create a pandas DataFrame using this list, to look like the table below?

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age', 'Nationality', '’Overall’']


df1 = pd.DataFrame(data= lst, columns= col, index=[1,2,3])

# %% [markdown]
# # Question 9
# Given the following numpy array
#
# array  = ([[94, 89, 63],
#           [93, 92, 48],  ![promo available.jpg](data:image/jpeg;base64,...![IMG_1736.JPEG](data:image/jpeg;base64,...))
#           [92, 94, 56]])

# %%
arr  = ([[94, 89, 63],
        [93, 92, 48],
        [92, 94, 56]])

a = np.array(arr)

a[:2, 1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %% [markdown]
# # Question 10
#
#
# How would you check for the number of rows and columns in a pandas DataFrame named df?

# %%
df.shape
# Out:
# (60943, 12)

# %% [markdown]
# # Question 12
# Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in 2017?

# %%
df.groupby('Area')['Y2017'].sum().sort_values(ascending=False).head(1)
# Out:
# Area
# Nigeria    1483268.23
# Name: Y2017, dtype: float64

# %% [markdown]
# # Question 13
# What is the total Protein supply quantity in Madagascar in 2015?

# %%
df[df['Element']== 'Protein supply quantity (g/capita/day)'].groupby('Area').get_group('Madagascar')['Y2015'].sum()
# Out:
# 173.04999999999998

# %% [markdown]
# # Question 14
# Consider the following list of tuples:
#
# y = [(2, 4), (7, 8), (1, 5, 9)]
#
# How would you assign element 8 from the list to a variable x?

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
x = y[1][1]

print(x)
# Out:
# 8

# %% [markdown]
# # Question 15
# What would be the output for?
#
# S = [['him', 'sell'], [90, 28, 43]]
#
# S[0][1][1]

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %% [markdown]
# # Question 16
# Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?

# %%
df.groupby('Element').get_group('Processing')['Y2017'].sum()
# Out:
# 292836.0

# %% [markdown]
# # Question 17
#
# Which of the following dataframe methods can be used to access elements across rows and columns?

# %%
df.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# # Question 18
#
# Given the following python code, what would the output of the code give?
#
# my_tuppy = (1,2,5,8)
#
# my_tuppy[2] = 6

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-0db9a3bcde61> in <cell line: 2>()
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Question 19
# Answer the following questions based on the African food production dataset provided by the FAO website already provided
#
# What is the total sum of Wine produced in 2015 and 2018 respectively?
#
# Hint:
#
# Perform a groupby sum aggregation on ‘Item’

# %%
Wine_2015 = df.groupby('Item').get_group('Wine')['Y2015'].sum()

Wine_2018 = df.groupby('Item').get_group('Wine')['Y2018'].sum()

print(round(Wine_2015, 2), round(Wine_2018, 2))
# Out:
# 4251.81 4039.32
